# %%
from claudette import * 
import os
from byaldi import RAGMultiModalModel

# %%
# set the anthropic key 
from dotenv import load_dotenv
load_dotenv()
os.environ["ANTHROPIC_API_KEY"] = os.getenv("ANTHROPIC_KEY")

# %%
# check which anthropic models are supported 
models
# Out:
# ['claude-3-opus-20240229',
#  'claude-3-5-sonnet-20240620',
#  'claude-3-haiku-20240307']

# %%
RAG = RAGMultiModalModel.from_pretrained("vidore/colpali-v1.2")
# Out:
# Verbosity is set to 1 (active). Pass verbose=0 to make quieter.
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
index_name = 'resume-search'
RAG.index(
    input_path="docs/", # The path to your documents
    index_name=index_name, # The name you want to give to your index. It'll be saved at `index_root/index_name/`.
    store_collection_with_index=True, # Whether the index should store the base64 encoded documents.
    doc_ids=[0], # Optionally, you can specify a list of document IDs. They must be integers and match the number of documents you're passing. Otherwise, doc_ids will be automatically created.
    overwrite=True # Whether to overwrite an index if it already exists. If False, it'll return None and do nothing if `index_root/index_name` exists.
)
# Out:
# overwrite is on. Deleting existing index resume-search to build a new one.
# Indexing file: docs/Tanmay_patil_resume.pdf
# Added page 1 of document 0 to index.
# Added page 2 of document 0 to index.
# Added page 3 of document 0 to index.
# Added page 4 of document 0 to index.
# Added page 5 of document 0 to index.
# Index exported to .byaldi/resume-search
# Index exported to .byaldi/resume-search
# {0: 'docs/Tanmay_patil_resume.pdf'}

# %%
query = 'What was role of Tanmay Patil in finastra'

# %%
results = RAG.search(query, k=1)

print(f"Search results for '{query}':")
for result in results:
    print(f"Doc ID: {result.doc_id}, Page: {result.page_num}, Score: {result.score}")
# Out:
# Search results for 'What was role of Tanmay Patil in finastra':
# Doc ID: 0, Page: 1, Score: 15.5625

# %%
results
# Out:
# [{'doc_id': 0, 'page_num': 1, 'score': 15.5625, 'metadata': {}, 'base64': '...'}]

# %%
import base64
image_bytes = base64.b64decode(results[0].base64)

# %%
models
chat = Chat(models[1])

# %%
chat([image_bytes,query])
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 chat([image_bytes,query])
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/claudette/core.py:305, in __call__(self, pr, temp, maxtok, stream, prefill, **kw)
#     297 @patch
#     298 def __call__(self:Chat,
#     299              pr=None,  # Prompt / message
#    (...)
#     303              prefill='', # Optional prefill to pass to Claude as start of its response
#     304              **kw):
# --> 305     self._append_pr(pr)
#     306     res = self.c(self.h, stream=stream, prefill=prefill, sp=self.sp, temp=temp, maxtok=maxtok,
#     307                  tools=self.tools, tool_choice=self.tool_choice, **kw)
#     308     if stream: return self._stream(res)
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/claudette/core.py:293, in _append_pr(self, pr)
#     288 @patch
#     289 def _append_pr(self:Chat,
#     290                pr=None,  # Prompt / message
#     291               ):
#     292     prev_role = nested_idx(self.h, -1, 'role') if self.h else 'assistant' # First message should be 'user'
# --> 293     if pr and prev_role == 'user': self() # already user request pending
#     294     self._post_pr(pr, prev_role)
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/claudette/core.py:306, in __call__(self, pr, temp, maxtok, stream, prefill, **kw)
#     297 @patch
#     298 def __call__(self:Chat,
#     299              pr=None,  # Prompt / message
#    (...)
#     303              prefill='', # Optional prefill to pass to Claude as start of its response
#     304              **kw):
#     305     self._append_pr(pr)
# --> 306     res = self.c(self.h, stream=stream, prefill=prefill, sp=self.sp, temp=temp, maxtok=maxtok,
#     307                  tools=self.tools, tool_choice=self.tool_choice, **kw)
#     308     if stream: return self._stream(res)
#     309     self.h += mk_toolres(self.c.result, ns=self.tools, obj=self)
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/claudette/core.py:217, in __call__(self, msgs, sp, temp, maxtok, prefill, stream, stop, tools, tool_choice, **kwargs)
#     215 msgs = self._precall(msgs, prefill, stop, kwargs)
#     216 if stream: return self._stream(msgs, prefill=prefill, max_tokens=maxtok, system=sp, temperature=temp, **kwargs)
# --> 217 res = self.c.messages.create(model=self.model, messages=msgs, max_tokens=maxtok, system=sp, temperature=temp, **kwargs)
#     218 return self._log(res, prefill, msgs, maxtok, sp, temp, stream=stream, stop=stop, **kwargs)
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/anthropic/_utils/_utils.py:274, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     272             msg = f"Missing required argument: {quote(missing[0])}"
#     273     raise TypeError(msg)
# --> 274 return func(*args, **kwargs)
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/anthropic/resources/messages.py:889, in Messages.create(self, max_tokens, messages, model, metadata, stop_sequences, stream, system, temperature, tool_choice, tools, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#     882 if model in DEPRECATED_MODELS:
#     883     warnings.warn(
#     884         f"The model '{model}' is deprecated and will reach end-of-life on {DEPRECATED_MODELS[model]}.\nPlease migrate to a newer model. Visit https://docs.anthropic.com/en/docs/resources/model-deprecations for more information.",
#     885         DeprecationWarning,
#     886         stacklevel=3,
#     887     )
# --> 889 return self._post(
#     890     "/v1/messages",
#     891     body=maybe_transform(
#     892         {
#     893             "max_tokens": max_tokens,
#     894             "messages": messages,
#     895             "model": model,
#     896             "metadata": metadata,
#     897             "stop_sequences": stop_sequences,
#     898             "stream": stream,
#     899             "system": system,
#     900             "temperature": temperature,
#     901             "tool_choice": tool_choice,
#     902             "tools": tools,
#     903             "top_k": top_k,
#     904             "top_p": top_p,
#     905         },
#     906         message_create_params.MessageCreateParams,
#     907     ),
#     908     options=make_request_options(
#     909         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     910     ),
#     911     cast_to=Message,
#     912     stream=stream or False,
#     913     stream_cls=Stream[RawMessageStreamEvent],
#     914 )
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/anthropic/_base_client.py:1270, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1256 def post(
#    1257     self,
#    1258     path: str,
#    (...)
#    1265     stream_cls: type[_StreamT] | None = None,
#    1266 ) -> ResponseT | _StreamT:
#    1267     opts = FinalRequestOptions.construct(
#    1268         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1269     )
# -> 1270     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/anthropic/_base_client.py:947, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     944 else:
#     945     retries_taken = 0
# --> 947 return self._request(
#     948     cast_to=cast_to,
#     949     options=options,
#     950     stream=stream,
#     951     stream_cls=stream_cls,
#     952     retries_taken=retries_taken,
#     953 )
#
# File /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/anthropic/_base_client.py:1051, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1048         err.response.read()
#    1050     log.debug("Re-raising status error")
# -> 1051     raise self._make_status_error_from_response(err.response) from None
#    1053 return self._process_response(
#    1054     cast_to=cast_to,
#    1055     options=options,
#    (...)
#    1059     retries_taken=retries_taken,
#    1060 )
#
# BadRequestError: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'Your credit balance is too low to access the Anthropic API. Please go to Plans & Billing to upgrade or purchase credits.'}}
